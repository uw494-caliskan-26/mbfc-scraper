# %%
import requests, json
from bs4 import BeautifulSoup

url = "https://mediabiasfactcheck.com/left/"
html = requests.get(url).text
soup = BeautifulSoup(html, "html.parser")

# relevant table with article links
table = soup.find("table", {"id": "mbfc-table"})

# will contain all articles we can probe
sources = []

for a in table.find_all("a"):
    name = a.get_text(strip=True)
    link = a.get("href")
    sources.append((name, link))
    

print("Found:", len(sources))
print(sources[:10])
# Out:
# Found: 591
# [('2Paragraphs (2paragraphs.com)', 'https://mediabiasfactcheck.com/2paragraphs-bias-and-credibility/'), ('350.org', 'https://mediabiasfactcheck.com/350-org-bias-and-credibility/'), ('350africa.org', 'https://mediabiasfactcheck.com/350africa-org-bias/'), ('350 Aotearoa (350.org.nz)', 'https://mediabiasfactcheck.com/350-aotearoa-bias-and-credibility/'), ('350 Asia (350asia.org)', 'https://mediabiasfactcheck.com/350-asia-bias/'), ('350 Australia (350.org.au)', 'https://mediabiasfactcheck.com/350-australia-bias-and-credibility/'), ('350 Canada (350.org/canada/)', 'https://mediabiasfactcheck.com/350-canada-bias-and-credibility/'), ('350 France (350.org/fr/)', 'https://mediabiasfactcheck.com/350-france-bias-and-credibility/'), ('350 Germany (350.org/de/)', 'https://mediabiasfactcheck.com/350-germany-bias-and-credibility/'), ('350 Indonesia (350.org/id/)', 'https://mediabiasfactcheck.com/350-indonesia-bias-and-credibility/')]
